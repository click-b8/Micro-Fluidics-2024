# %% [markdown]
# <a href="https://colab.research.google.com/github/click-b8/Micro-Fluidics-2024/blob/main/Microfluidics_midterm_prob6ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# Given parameters
diameter = 50  # Diameter of microchannel in micrometers
flow_rate= 2    # Flow rate in microliters per minute
viscosity = 1.5       # Viscosity of the liquid in milliPascal-seconds

# Convert flow rate from microliters per minute to cubic meters per second
flow_rate_m3_per_s = flow_rate_ul_per_min * (1e-6 / 60)

# Convert diameter from micrometers to meters and calculate radius
radius_meters = diameter_micrometers * 1e-6 / 2

# Calculate cross-sectional area of the microchannel
area_m2 = math.pi * radius_meters**2

# Use Hagen-Poiseuille equation to calculate pressure drop
pressure_drop = 8 * viscosity_mPa_s * flow_rate_m3_per_s / (math.pi * radius_meters**4)

# Calculate average velocity of the liquid flow within the microchannel
average_velocity_m_per_s = flow_rate_m3_per_s / area_m2

print("Pressure drop along the microchannel:", pressure_drop, "Pa")
print("Average velocity of the liquid flow within the microchannel:", average_velocity_m_per_s, "m/s")


# Create a range of positions along the microchannel
num_points = 100
positions = np.linspace(0, diameter, num_points)

# Calculate flow profile using parabolic velocity distribution
flow_profile = (4 * velocity / diameter) * (radius ** 2 - (positions - radius) ** 2)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(positions * 1e6, flow_profile * 1e6, color='blue')
plt.title('Flow Profile in Microchannel')
plt.xlabel('Position along Microchannel (µm)')
plt.ylabel('Velocity (µm/s)')
plt.grid(True)
plt.show()
# Out:
# Pressure drop along the microchannel: 325949323452.2018 Pa
# Average velocity of the liquid flow within the microchannel: 16.97652726313551 m/s

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given parameters
diameter = 50e-6  # diameter of the microchannel in meters
viscosity = 1.5e-3  # viscosity of the liquid in Pa·s
flow_rate = 2e-9  # flow rate in m³/s

# Calculating radius and cross-sectional area
radius = diameter / 2
area = np.pi * radius ** 2

# Calculate velocity using the Hagen-Poiseuille equation
velocity = flow_rate / area

# Use Hagen-Poiseuille equation to calculate pressure drop
pressure_drop = 8 * viscosity_mPa_s * flow_rate_m3_per_s / (math.pi * radius_meters**4)

print("Pressure drop along the microchannel:", pressure_drop, "Pa")
print("Average velocity of the liquid flow within the microchannel:", average_velocity_m_per_s, "m/s")



# Create a range of positions along the microchannel
num_points = 100
positions = np.linspace(0, diameter, num_points)

# Calculate flow profile using parabolic velocity distribution
flow_profile = (4 * velocity / diameter) * (radius ** 2 - (positions - radius) ** 2)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(positions * 1e6, flow_profile * 1e6, color='blue')
plt.title('Flow Profile in Microchannel')
plt.xlabel('Position along Microchannel (µm)')
plt.ylabel('Velocity (µm/s)')
plt.grid(True)
plt.show()
# Out:
# Pressure drop along the microchannel: 325949323452.2018 Pa
# Average velocity of the liquid flow within the microchannel: 16.97652726313551 m/s
